# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
pd.set_option('display.max_rows', 100)

# %%
gdf_agencias_sp = pd.read_csv('C:/Users/Ricardo/Documents/R-Projetos/Exploratory-Data-Analysis-Bancarization/data/processed/agencias_latlong.csv', sep=';')

# %%
df = pd.concat(map(pd.read_csv, ['C:/Users/Ricardo/Documents/R-Projetos/Exploratory-Data-Analysis-Bancarization/data/processed/simulations_results/result_sim_6_1.csv', 'C:/Users/Ricardo/Documents/R-Projetos/Exploratory-Data-Analysis-Bancarization/data/processed/simulations_results/result_sim_6_2.csv','C:/Users/Ricardo/Documents/R-Projetos/Exploratory-Data-Analysis-Bancarization/data/processed/simulations_results/result_sim_6_3.csv', 'C:/Users/Ricardo/Documents/R-Projetos/Exploratory-Data-Analysis-Bancarization/data/processed/simulations_results/result_sim_6_4.csv', 'C:/Users/Ricardo/Documents/R-Projetos/Exploratory-Data-Analysis-Bancarization/data/processed/simulations_results/result_sim_6_5.csv', 'C:/Users/Ricardo/Documents/R-Projetos/Exploratory-Data-Analysis-Bancarization/data/processed/simulations_results/result_sim_6_6.csv', 'C:/Users/Ricardo/Documents/R-Projetos/Exploratory-Data-Analysis-Bancarization/data/processed/simulations_results/result_sim_6_7.csv', 'C:/Users/Ricardo/Documents/R-Projetos/Exploratory-Data-Analysis-Bancarization/data/processed/simulations_results/result_sim_6_8.csv', 'C:/Users/Ricardo/Documents/R-Projetos/Exploratory-Data-Analysis-Bancarization/data/processed/simulations_results/result_sim_6_9.csv', 'C:/Users/Ricardo/Documents/R-Projetos/Exploratory-Data-Analysis-Bancarization/data/processed/simulations_results/result_sim_6_10.csv']))

# %%
df
# Out:
#          simulacao  pop_total  pop_buffer  perc_atendimento   nome_distrito  \
# 0    simulacao_6_1      70923        2725          0.038422  JOSE BONIFACIO
# 1    simulacao_6_1     148795       24513          0.164743     JD SAO LUIS
# 2    simulacao_6_1      53289        9598          0.180112     ARTUR ALVIM
# 3    simulacao_6_1      12937        3917          0.302775         JAGUARA
# 4    simulacao_6_1      57243       27224          0.475587   VILA PRUDENTE
# ..             ...        ...         ...               ...             ...
# 91  simulacao_6_10      58141       22790          0.391978      VILA MARIA
# 92  simulacao_6_10      76056       59058          0.776507    VILA MARIANA
# 93  simulacao_6_10      56905       18013          0.316545    VILA MATILDE
# 94  simulacao_6_10      49577       47817          0.964500   SANTA CECILIA
# 95  simulacao_6_10      34609       34609          1.000000       REPUBLICA
#
#     cod_distrito
# 0             47
# 1             46
# 2              5
# 3             40
# 4             93
# ..           ...
# 91            89
# 92            90
# 93            91
# 94            69
# 95            66
#
# [960 rows x 6 columns]

# %%
heatmap = df[['simulacao', 'perc_atendimento', 'nome_distrito']].pivot(index='nome_distrito', columns='simulacao')['perc_atendimento']
fig,ax = plt.subplots(1,1,figsize=(18,28))
sns.heatmap(heatmap, cmap="Blues", annot=True, ax=ax)
# Out:
# <AxesSubplot:xlabel='simulacao', ylabel='nome_distrito'>

# %%
df_agg_sd = df.groupby(['cod_distrito', 'nome_distrito']).agg({'perc_atendimento':'std'}) \
                          .reset_index()

# %%
df_agg_sd
# Out:
#     cod_distrito       nome_distrito  perc_atendimento
# 0              1           AGUA RASA          0.001737
# 1              2   ALTO DE PINHEIROS          0.003445
# 2              3          ANHANGUERA          0.000000
# 3              4          ARICANDUVA          0.001476
# 4              5         ARTUR ALVIM          0.001768
# 5              6         BARRA FUNDA          0.002706
# 6              7          BELA VISTA          0.000270
# 7              8               BELEM          0.002518
# 8              9          BOM RETIRO          0.003147
# 9             10                BRAS          0.001844
# 10            11         BRASILANDIA          0.000682
# 11            12             BUTANTA          0.001674
# 12            13        CACHOEIRINHA          0.001099
# 13            14             CAMBUCI          0.002946
# 14            15          CAMPO BELO          0.002922
# 15            16        CAMPO GRANDE          0.001898
# 16            17         CAMPO LIMPO          0.000983
# 17            18            CANGAIBA          0.000804
# 18            19       CAPAO REDONDO          0.001364
# 19            20              CARRAO          0.002619
# 20            21          CASA VERDE          0.003700
# 21            22          CID ADEMAR          0.001061
# 22            23           CID DUTRA          0.001158
# 23            24           CID LIDER          0.000817
# 24            25      CID TIRADENTES          0.000000
# 25            26          CONSOLACAO          0.001510
# 26            27             CURSINO          0.001474
# 27            28  ERMELINO MATARAZZO          0.001129
# 28            29      FREGUESIA DO O          0.002008
# 29            30              GRAJAU          0.000372
# 30            31          GUAIANASES          0.001583
# 31            32               MOEMA          0.001126
# 32            33            IGUATEMI          0.000915
# 33            34            IPIRANGA          0.002104
# 34            35          ITAIM BIBI          0.000432
# 35            36      ITAIM PAULISTA          0.001335
# 36            37            ITAQUERA          0.001391
# 37            38           JABAQUARA          0.001372
# 38            39              JACANA          0.001423
# 39            40             JAGUARA          0.005030
# 40            41             JAGUARE          0.003573
# 41            42             JARAGUA          0.000777
# 42            43           JD ANGELA          0.000474
# 43            44           JD HELENA          0.001195
# 44            45         JD PAULISTA          0.000518
# 45            46         JD SAO LUIS          0.000928
# 46            47      JOSE BONIFACIO          0.000756
# 47            48                LAPA          0.002750
# 48            49           LIBERDADE          0.001395
# 49            50               LIMAO          0.002353
# 50            51            MANDAQUI          0.001016
# 51            52            MARSILAC          0.000000
# 52            53               MOOCA          0.002069
# 53            54             MORUMBI          0.002750
# 54            55         PARELHEIROS          0.000426
# 55            56                PARI          0.004875
# 56            57     PARQUE DO CARMO          0.001631
# 57            58            PEDREIRA          0.000000
# 58            59               PENHA          0.002525
# 59            60            PERDIZES          0.001480
# 60            61               PERUS          0.001353
# 61            62           PINHEIROS          0.001533
# 62            63            PIRITUBA          0.001582
# 63            64          PONTE RASA          0.001350
# 64            65      RAPOSO TAVARES          0.002050
# 65            66           REPUBLICA          0.000000
# 66            67         RIO PEQUENO          0.001635
# 67            68              SACOMA          0.001385
# 68            69       SANTA CECILIA          0.000952
# 69            70             SANTANA          0.001741
# 70            71         SANTO AMARO          0.002126
# 71            72           SAO LUCAS          0.001300
# 72            73          SAO MATEUS          0.001823
# 73            74          SAO MIGUEL          0.001938
# 74            75          SAO RAFAEL          0.001106
# 75            76           SAPOPEMBA          0.001360
# 76            77               SAUDE          0.001281
# 77            78                  SE          0.001267
# 78            79             SOCORRO          0.002902
# 79            80             TATUAPE          0.002023
# 80            81            TREMEMBE          0.000641
# 81            82            TUCURUVI          0.002468
# 82            83        VILA ANDRADE          0.001241
# 83            84         VILA CURUCA          0.000996
# 84            85        VILA FORMOSA          0.002006
# 85            86      VILA GUILHERME          0.003409
# 86            87          VILA JACUI          0.001182
# 87            88     VILA LEOPOLDINA          0.002343
# 88            89          VILA MARIA          0.002468
# 89            90        VILA MARIANA          0.001745
# 90            91        VILA MATILDE          0.001554
# 91            92       VILA MEDEIROS          0.002227
# 92            93       VILA PRUDENTE          0.001813
# 93            94          VILA SONIA          0.001678
# 94            95        SAO DOMINGOS          0.002509
# 95            96             LAJEADO          0.000678

# %%
df_agg = df.groupby(['cod_distrito', 'nome_distrito']).agg({'perc_atendimento':'mean'}) \
                          .reset_index()

# %%
df_agg
# Out:
#     cod_distrito       nome_distrito  perc_atendimento
# 0              1           AGUA RASA          0.480838
# 1              2   ALTO DE PINHEIROS          0.260274
# 2              3          ANHANGUERA          0.000000
# 3              4          ARICANDUVA          0.337657
# 4              5         ARTUR ALVIM          0.180037
# 5              6         BARRA FUNDA          0.686789
# 6              7          BELA VISTA          0.992513
# 7              8               BELEM          0.371468
# 8              9          BOM RETIRO          0.709561
# 9             10                BRAS          0.856252
# 10            11         BRASILANDIA          0.074349
# 11            12             BUTANTA          0.311472
# 12            13        CACHOEIRINHA          0.207394
# 13            14             CAMBUCI          0.597361
# 14            15          CAMPO BELO          0.740926
# 15            16        CAMPO GRANDE          0.348199
# 16            17         CAMPO LIMPO          0.141577
# 17            18            CANGAIBA          0.104325
# 18            19       CAPAO REDONDO          0.256169
# 19            20              CARRAO          0.469748
# 20            21          CASA VERDE          0.489306
# 21            22          CID ADEMAR          0.350221
# 22            23           CID DUTRA          0.120204
# 23            24           CID LIDER          0.069228
# 24            25      CID TIRADENTES          0.000000
# 25            26          CONSOLACAO          0.875367
# 26            27             CURSINO          0.295137
# 27            28  ERMELINO MATARAZZO          0.248520
# 28            29      FREGUESIA DO O          0.378370
# 29            30              GRAJAU          0.016918
# 30            31          GUAIANASES          0.120297
# 31            32               MOEMA          0.806533
# 32            33            IGUATEMI          0.091405
# 33            34            IPIRANGA          0.481306
# 34            35          ITAIM BIBI          0.988459
# 35            36      ITAIM PAULISTA          0.222623
# 36            37            ITAQUERA          0.387769
# 37            38           JABAQUARA          0.369494
# 38            39              JACANA          0.154621
# 39            40             JAGUARA          0.304352
# 40            41             JAGUARE          0.261446
# 41            42             JARAGUA          0.086255
# 42            43           JD ANGELA          0.024606
# 43            44           JD HELENA          0.141979
# 44            45         JD PAULISTA          0.953692
# 45            46         JD SAO LUIS          0.165276
# 46            47      JOSE BONIFACIO          0.039372
# 47            48                LAPA          0.526679
# 48            49           LIBERDADE          0.806787
# 49            50               LIMAO          0.372360
# 50            51            MANDAQUI          0.212376
# 51            52            MARSILAC          0.000000
# 52            53               MOOCA          0.635208
# 53            54             MORUMBI          0.409727
# 54            55         PARELHEIROS          0.012885
# 55            56                PARI          0.761914
# 56            57     PARQUE DO CARMO          0.074849
# 57            58            PEDREIRA          0.000000
# 58            59               PENHA          0.489688
# 59            60            PERDIZES          0.799283
# 60            61               PERUS          0.045443
# 61            62           PINHEIROS          0.877251
# 62            63            PIRITUBA          0.136594
# 63            64          PONTE RASA          0.344086
# 64            65      RAPOSO TAVARES          0.166691
# 65            66           REPUBLICA          1.000000
# 66            67         RIO PEQUENO          0.402989
# 67            68              SACOMA          0.429938
# 68            69       SANTA CECILIA          0.964167
# 69            70             SANTANA          0.515243
# 70            71         SANTO AMARO          0.634017
# 71            72           SAO LUCAS          0.476251
# 72            73          SAO MATEUS          0.446779
# 73            74          SAO MIGUEL          0.368049
# 74            75          SAO RAFAEL          0.060147
# 75            76           SAPOPEMBA          0.323024
# 76            77               SAUDE          0.760299
# 77            78                  SE          0.973552
# 78            79             SOCORRO          0.229191
# 79            80             TATUAPE          0.731692
# 80            81            TREMEMBE          0.036316
# 81            82            TUCURUVI          0.543839
# 82            83        VILA ANDRADE          0.385003
# 83            84         VILA CURUCA          0.136826
# 84            85        VILA FORMOSA          0.431355
# 85            86      VILA GUILHERME          0.507140
# 86            87          VILA JACUI          0.184919
# 87            88     VILA LEOPOLDINA          0.555637
# 88            89          VILA MARIA          0.393672
# 89            90        VILA MARIANA          0.777682
# 90            91        VILA MATILDE          0.317260
# 91            92       VILA MEDEIROS          0.508530
# 92            93       VILA PRUDENTE          0.477791
# 93            94          VILA SONIA          0.185189
# 94            95        SAO DOMINGOS          0.331054
# 95            96             LAJEADO          0.089106

# %%
sp_shp = gpd.read_file('C:/Users/Ricardo/Documents/R-Projetos/Exploratory-Data-Analysis-Bancarization/data/processed/sp_pop_shp/sp_pop_shp.shp')

# %%
sp_shp_agg = sp_shp.merge(df_agg, how='left',left_on='COD_DIST', right_on='cod_distrito')

# %%
fig, ax = plt.subplots(figsize=(40,34))

# Set bg colors
ax.set(facecolor = "white")
fig.patch.set_facecolor('white')

# Plot
sp_shp_agg.plot(column='perc_atendimento', cmap="Blues", legend=True, ax=ax)

# Add district name
for x, y, label in zip(sp_shp_agg.centroid.x, sp_shp_agg.centroid.y, sp_shp_agg.nome_distrito):
  ax.annotate(label, xy=(x, y), xytext=(-10, 0), textcoords="offset points", fontsize=8)

ax.axis("off")
plt.show()
